# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/My Drive/Colab Notebooks/Final Project/chest_xray.zip", 'r')

zip_ref.extractall("/tmp")
zip_ref.close()

# %%
import os
import keras
# Out:
# Using TensorFlow backend.

# %%
# !ls "/tmp/chest_xray/"
# Out:
# test  train  val

# %%
base_dir = '/tmp/chest_xray/'

#the original dataset interchanged 'test' with 'validation,' with the latter being the 'holdout' dataset
# train_dir = os.path.join(base_dir, 'train')
# test_dir = os.path.join(base_dir, 'test')
# validation_dir = os.path.join(base_dir, 'val')

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

# %%
# dimensions of our images.
img_width, img_height = 150, 150

train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
val_dir = os.path.join(base_dir, 'val')
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 1)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
history = model.fit_generator(train_generator,
                              steps_per_epoch=nb_train_samples // batch_size,
                              epochs=epochs,
                              validation_data=test_generator,
                              validation_steps=nb_validation_samples // batch_size)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 26s 208ms/step - loss: 0.5527 - accuracy: 0.7355 - val_loss: 0.5908 - val_accuracy: 0.6812
# Epoch 2/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.3678 - accuracy: 0.8470 - val_loss: 0.3228 - val_accuracy: 0.8525
# Epoch 3/50
# 125/125 [==============================] - 24s 189ms/step - loss: 0.2978 - accuracy: 0.8810 - val_loss: 0.3235 - val_accuracy: 0.7600
# Epoch 4/50
# 125/125 [==============================] - 25s 196ms/step - loss: 0.3050 - accuracy: 0.8845 - val_loss: 0.2623 - val_accuracy: 0.8275
# Epoch 5/50
# 125/125 [==============================] - 24s 189ms/step - loss: 0.2701 - accuracy: 0.8900 - val_loss: 0.6343 - val_accuracy: 0.7500
# Epoch 6/50
# 125/125 [==============================] - 24s 192ms/step - loss: 0.2611 - accuracy: 0.9100 - val_loss: 0.8068 - val_accuracy: 0.8388
# Epoch 7/50
# 125/125 [==============================] - 24s 189ms/step - loss: 0.2472 - accuracy: 0.9075 - val_loss: 0.2531 - val_accuracy: 0.8350
# Epoch 8/50
# 125/125 [==============================] - 25s 198ms/step - loss: 0.2266 - accuracy: 0.9165 - val_loss: 0.3853 - val_accuracy: 0.8512
# Epoch 9/50
# 125/125 [==============================] - 24s 188ms/step - loss: 0.2096 - accuracy: 0.9320 - val_loss: 1.0111 - val_accuracy: 0.8050
# Epoch 10/50
# 125/125 [==============================] - 24s 195ms/step - loss: 0.2177 - accuracy: 0.9235 - val_loss: 0.4634 - val_accuracy: 0.8450
# Epoch 11/50
# 125/125 [==============================] - 24s 194ms/step - loss: 0.2132 - accuracy: 0.9190 - val_loss: 0.2975 - val_accuracy: 0.8600
# Epoch 12/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.2166 - accuracy: 0.9300 - val_loss: 0.5843 - val_accuracy: 0.7975
# Epoch 13/50
# 125/125 [==============================] - 23s 188ms/step - loss: 0.2227 - accuracy: 0.9370 - val_loss: 0.7646 - val_accuracy: 0.8138
# Epoch 14/50
# 125/125 [==============================] - 25s 202ms/step - loss: 0.2098 - accuracy: 0.9350 - val_loss: 0.3031 - val_accuracy: 0.8562
# Epoch 15/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.2161 - accuracy: 0.9290 - val_loss: 0.5447 - val_accuracy: 0.8938
# Epoch 16/50
# 125/125 [==============================] - 24s 189ms/step - loss: 0.1863 - accuracy: 0.9395 - val_loss: 0.7631 - val_accuracy: 0.8500
# Epoch 17/50
# 125/125 [==============================] - 24s 189ms/step - loss: 0.1847 - accuracy: 0.9445 - val_loss: 0.0716 - val_accuracy: 0.8850
# Epoch 18/50
# 125/125 [==============================] - 24s 191ms/step - loss: 0.2106 - accuracy: 0.9285 - val_loss: 0.0200 - val_accuracy: 0.9050
# Epoch 19/50
# 125/125 [==============================] - 24s 193ms/step - loss: 0.1838 - accuracy: 0.9425 - val_loss: 0.4409 - val_accuracy: 0.8888
# Epoch 20/50
# 125/125 [==============================] - 24s 191ms/step - loss: 0.1947 - accuracy: 0.9305 - val_loss: 0.1960 - val_accuracy: 0.8350
# Epoch 21/50
# 125/125 [==============================] - 24s 193ms/step - loss: 0.2121 - accuracy: 0.9335 - val_loss: 0.1756 - val_accuracy: 0.8712
# Epoch 22/50
# 125/125 [==============================] - 24s 195ms/step - loss: 0.1956 - accuracy: 0.9375 - val_loss: 0.4451 - val_accuracy: 0.8587
# Epoch 23/50
# 125/125 [==============================] - 24s 195ms/step - loss: 0.1928 - accuracy: 0.9345 - val_loss: 0.3879 - val_accuracy: 0.9000
# Epoch 24/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.1826 - accuracy: 0.9475 - val_loss: 0.0397 - val_accuracy: 0.9025
# Epoch 25/50
# 125/125 [==============================] - 24s 195ms/step - loss: 0.1981 - accuracy: 0.9355 - val_loss: 0.4060 - val_accuracy: 0.9050
# Epoch 26/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.1892 - accuracy: 0.9400 - val_loss: 2.0736 - val_accuracy: 0.8788
# Epoch 27/50
# 125/125 [==============================] - 24s 196ms/step - loss: 0.2008 - accuracy: 0.9335 - val_loss: 3.2499 - val_accuracy: 0.7337
# Epoch 28/50
# 125/125 [==============================] - 23s 187ms/step - loss: 0.1701 - accuracy: 0.9485 - val_loss: 0.4029 - val_accuracy: 0.7862
# Epoch 29/50
# 125/125 [==============================] - 25s 197ms/step - loss: 0.1823 - accuracy: 0.9435 - val_loss: 0.3063 - val_accuracy: 0.8863
# Epoch 30/50
# 125/125 [==============================] - 25s 197ms/step - loss: 0.2007 - accuracy: 0.9390 - val_loss: 0.0804 - val_accuracy: 0.8575
# Epoch 31/50
# 125/125 [==============================] - 23s 186ms/step - loss: 0.1935 - accuracy: 0.9370 - val_loss: 1.5750 - val_accuracy: 0.7275
# Epoch 32/50
# 125/125 [==============================] - 24s 192ms/step - loss: 0.1855 - accuracy: 0.9410 - val_loss: 0.1446 - val_accuracy: 0.7763
# Epoch 33/50
# 125/125 [==============================] - 24s 193ms/step - loss: 0.1828 - accuracy: 0.9470 - val_loss: 0.7848 - val_accuracy: 0.8512
# Epoch 34/50
# 125/125 [==============================] - 25s 197ms/step - loss: 0.1994 - accuracy: 0.9405 - val_loss: 1.1107 - val_accuracy: 0.8300
# Epoch 35/50
# 125/125 [==============================] - 24s 194ms/step - loss: 0.1836 - accuracy: 0.9455 - val_loss: 0.4869 - val_accuracy: 0.9100
# Epoch 36/50
# 125/125 [==============================] - 24s 195ms/step - loss: 0.1903 - accuracy: 0.9420 - val_loss: 0.1820 - val_accuracy: 0.8712
# Epoch 37/50
# 125/125 [==============================] - 24s 192ms/step - loss: 0.1747 - accuracy: 0.9465 - val_loss: 0.4745 - val_accuracy: 0.8525
# Epoch 38/50
# 125/125 [==============================] - 24s 191ms/step - loss: 0.1937 - accuracy: 0.9335 - val_loss: 0.2884 - val_accuracy: 0.8188
# Epoch 39/50
# 125/125 [==============================] - 24s 193ms/step - loss: 0.2136 - accuracy: 0.9375 - val_loss: 0.4362 - val_accuracy: 0.8425
# Epoch 40/50
# 125/125 [==============================] - 24s 189ms/step - loss: 0.1612 - accuracy: 0.9485 - val_loss: 0.3221 - val_accuracy: 0.8888
# Epoch 41/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.2119 - accuracy: 0.9475 - val_loss: 0.0204 - val_accuracy: 0.9075
# Epoch 42/50
# 125/125 [==============================] - 24s 191ms/step - loss: 0.1909 - accuracy: 0.9370 - val_loss: 0.5915 - val_accuracy: 0.8550
# Epoch 43/50
# 125/125 [==============================] - 24s 192ms/step - loss: 0.1728 - accuracy: 0.9470 - val_loss: 1.2245e-04 - val_accuracy: 0.8250
# Epoch 44/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.1834 - accuracy: 0.9430 - val_loss: 0.3295 - val_accuracy: 0.8788
# Epoch 45/50
# 125/125 [==============================] - 24s 190ms/step - loss: 0.1663 - accuracy: 0.9450 - val_loss: 0.3228 - val_accuracy: 0.9062
# Epoch 46/50
# 125/125 [==============================] - 24s 192ms/step - loss: 0.1761 - accuracy: 0.9500 - val_loss: 0.0702 - val_accuracy: 0.8875
# Epoch 47/50
# 125/125 [==============================] - 24s 192ms/step - loss: 0.1947 - accuracy: 0.9445 - val_loss: 0.0322 - val_accuracy: 0.8550
# Epoch 48/50
# 125/125 [==============================] - 23s 187ms/step - loss: 0.1592 - accuracy: 0.9560 - val_loss: 1.2360 - val_accuracy: 0.8275
# Epoch 49/50
# 125/125 [==============================] - 24s 193ms/step - loss: 0.1947 - accuracy: 0.9410 - val_loss: 1.2824 - val_accuracy: 0.8675
# Epoch 50/50
# 125/125 [==============================] - 24s 192ms/step - loss: 0.2018 - accuracy: 0.9405 - val_loss: 0.4118 - val_accuracy: 0.8350

# %%
import pandas as pd
import numpy as np

# %%
history_df = pd.DataFrame(history.history)

history_df
# Out:
#     val_loss  val_accuracy      loss  accuracy
# 0   0.590772       0.68125  0.552690    0.7355
# 1   0.322793       0.85250  0.367792    0.8470
# 2   0.323459       0.76000  0.297791    0.8810
# 3   0.262259       0.82750  0.304968    0.8845
# 4   0.634335       0.75000  0.270081    0.8900
# 5   0.806834       0.83875  0.261103    0.9100
# 6   0.253095       0.83500  0.247176    0.9075
# 7   0.385289       0.85125  0.226595    0.9165
# 8   1.011089       0.80500  0.209623    0.9320
# 9   0.463437       0.84500  0.217738    0.9235
# 10  0.297539       0.86000  0.213203    0.9190
# 11  0.584342       0.79750  0.216558    0.9300
# 12  0.764602       0.81375  0.222658    0.9370
# 13  0.303098       0.85625  0.209803    0.9350
# 14  0.544680       0.89375  0.216123    0.9290
# 15  0.763149       0.85000  0.186257    0.9395
# 16  0.071633       0.88500  0.184707    0.9445
# 17  0.019955       0.90500  0.210601    0.9285
# 18  0.440917       0.88875  0.183791    0.9425
# 19  0.196019       0.83500  0.194679    0.9305
# 20  0.175628       0.87125  0.212149    0.9335
# 21  0.445109       0.85875  0.195620    0.9375
# 22  0.387887       0.90000  0.192762    0.9345
# 23  0.039709       0.90250  0.182632    0.9475
# 24  0.405979       0.90500  0.198147    0.9355
# 25  2.073612       0.87875  0.189207    0.9400
# 26  3.249904       0.73375  0.200784    0.9335
# 27  0.402918       0.78625  0.170145    0.9485
# 28  0.306349       0.88625  0.182299    0.9435
# 29  0.080360       0.85750  0.200670    0.9390
# 30  1.574960       0.72750  0.193477    0.9370
# 31  0.144632       0.77625  0.185465    0.9410
# 32  0.784755       0.85125  0.182784    0.9470
# 33  1.110667       0.83000  0.199413    0.9405
# 34  0.486932       0.91000  0.183574    0.9455
# 35  0.182013       0.87125  0.190346    0.9420
# 36  0.474454       0.85250  0.174654    0.9465
# 37  0.288408       0.81875  0.193697    0.9335
# 38  0.436246       0.84250  0.213553    0.9375
# 39  0.322091       0.88875  0.161186    0.9485
# 40  0.020389       0.90750  0.211850    0.9475
# 41  0.591482       0.85500  0.190908    0.9370
# 42  0.000122       0.82500  0.172808    0.9470
# 43  0.329491       0.87875  0.183434    0.9430
# 44  0.322846       0.90625  0.166268    0.9450
# 45  0.070174       0.88750  0.176093    0.9500
# 46  0.032235       0.85500  0.194736    0.9445
# 47  1.236039       0.82750  0.159209    0.9560
# 48  1.282400       0.86750  0.194698    0.9410
# 49  0.411803       0.83500  0.201825    0.9405

# %%
val_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical')


test_generator.reset()

pred = model.predict_generator(val_generator,verbose=1)

predicted_class_indices=np.argmax(pred,axis=1)

labels = (val_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

filenames=val_generator.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})

print(results.to_string())
# Out:
# Found 16 images belonging to 2 classes.
# 1/1 [==============================] - 0s 153ms/step
#                                    Filename Predictions
# 0          NORMAL/NORMAL2-IM-1427-0001.jpeg   PNEUMONIA
# 1          NORMAL/NORMAL2-IM-1430-0001.jpeg   PNEUMONIA
# 2          NORMAL/NORMAL2-IM-1431-0001.jpeg   PNEUMONIA
# 3          NORMAL/NORMAL2-IM-1436-0001.jpeg   PNEUMONIA
# 4          NORMAL/NORMAL2-IM-1437-0001.jpeg   PNEUMONIA
# 5          NORMAL/NORMAL2-IM-1438-0001.jpeg   PNEUMONIA
# 6          NORMAL/NORMAL2-IM-1440-0001.jpeg   PNEUMONIA
# 7          NORMAL/NORMAL2-IM-1442-0001.jpeg   PNEUMONIA
# 8   PNEUMONIA/person1946_bacteria_4874.jpeg   PNEUMONIA
# 9   PNEUMONIA/person1946_bacteria_4875.jpeg   PNEUMONIA
# 10  PNEUMONIA/person1947_bacteria_4876.jpeg      NORMAL
# 11  PNEUMONIA/person1949_bacteria_4880.jpeg      NORMAL
# 12  PNEUMONIA/person1950_bacteria_4881.jpeg   PNEUMONIA
# 13  PNEUMONIA/person1951_bacteria_4882.jpeg   PNEUMONIA
# 14  PNEUMONIA/person1952_bacteria_4883.jpeg   PNEUMONIA
# 15  PNEUMONIA/person1954_bacteria_4886.jpeg   PNEUMONIA

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import model_from_json

# save_path = '/content/drive/My Drive/Colab Notebooks/Final Project/models/chollet_imbalanced/'

# dot_img_file = '/content/drive/My Drive/Colab Notebooks/Final Project/images/Chollet_imbalanced.png'
# plot_model(model, to_file=dot_img_file, show_shapes=True)

results.to_csv('/content/drive/My Drive/Colab Notebooks/Final Project/models/chollet_imbalanced/chollet_imbal_eval.csv', index=False)
history_df.to_csv('/content/drive/My Drive/Colab Notebooks/Final Project/models/chollet_imbalanced/chollet_imbal_acc.csv', index=False)

model_json = model.to_json()
with open('/content/drive/My Drive/Colab Notebooks/Final Project/models/chollet_imbalanced/chollet_imbal_model.json', 'w') as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights('/content/drive/My Drive/Colab Notebooks/Final Project/models/chollet_imbalanced/chollet_imbal_model.h5')
